# %%
import pandas as pd

df_caracteristiques = pd.read_csv("stacked_files/caracteristiques_stacked_python.csv", sep=";", dtype=str)
df_lieux = pd.read_csv("stacked_files/lieux_stacked_python.csv", sep=";", dtype=str)
df_vehicules = pd.read_csv("stacked_files/vehicules_stacked_python.csv", sep=";", dtype=str)
df_usagers = pd.read_csv("stacked_files/usagers_stacked_python.csv", sep=";", dtype=str)

# %% [markdown]
# ON FAIT LE MAPPING DES VALEURS POUR REMPLACER LES 1/2/3/...

# %%
mapping_caracteristiques = {
                        "agg":{
                            "1":"1 - Hors agglomération",
                            "2":"2 - En agglomération"},

                        "int":{
                            "1":"1 - Hors intersection",
                            "2":"2 - Intersection en X",
                            "3":"3 - Intersection en T",
                            "4":"4 - Intersection en Y",
                            "5":"5 - Intersection à plus de 4 branches",
                            "6":"6 - Giratoire",
                            "7":"7 - Place",
                            "8":"8 - Passage à niveau",
                            "9":"9 - Autre intersection"},

                        "atm":{
                            "-1":"-1 - Non renseigné",
                            "1":"1 - Normale",
                            "2":"2 - Pluie légère",
                            "3":"3 - Pluie forte",
                            "4":"4 - Neige - grêle",
                            "5":"5 - Brouillard - fumée",
                            "6":"6 - Vent fort - tempête",
                            "7":"7 - Temps éblouissant",
                            "8":"8 - Temps couvert",
                            "9":"9 - Autre"},

                        "col":{
                            "-1":"-1 - Non renseigné",
                            "1":"1 - Deux véhicules - frontale",
                            "2":"2 - Deux véhicules - par l'arrière",
                            "3":"3 - Deux véhicules - par le coté",
                            "4":" 4 - Trois véhicules et plus - en chaîne",
                            "5":"5 - Trois véhicules et plus - collisions multiples",
                            "6":"6 - Autre collision",
                            "7":"7 - Sans collision"}



}

# %%
mapping_lieux = {'catr':{ 
                        "1":"1 - Autoroute",
                        "2":"2 - Route nationale",
                        "3":"3 - Route Départementale",
                        "4":"4 - Voie Communales",
                        "5":"5 - Hors réseau public",
                        "6":"6 - Parc de stationnement ouvert à la circulation publique",
                        "7":"7 - Routes de métropole urbaine",
                        "9":"9 - autre"},
                        
                'circ':{ 
                        "-1":"-1 - Non renseigné",
                        "1":"1 - A sens unique",
                        "2":"2 - Bidirectionnelle",
                        "3":"3 - A chaussées séparées",
                        "4":"4 - Avec voies d'affectation variable"},

                'vosp':{   
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Sans objet",
                        "1":"1 - Piste cyclable",
                        "2":"2 - Bande cyclable",
                        "3":"3 - Voie réservée"},
                        
                "prof":{   
                        "-1":"-1 - Non renseigné",
                        "1":"1 - Plat",
                        "2":"2 - Pente",
                        "3":"3 - Sommet de côte",
                        "4":"4 - Bas de côte"},
                        
                "plan":{
                        "-1":"-1 - Non renseigné",
                        "1":"1 - Partie rectiligne",
                        "2":"2 - En courbe à gauche",
                        "3":"3 - En courbe à droite",
                        "4":"4 - En « S »"},

                "surf":{
                        "-1":"-1 - Non renseigné",
                        "1":"1 - Normale",
                        "2":"2 - Mouillée",
                        "3":"3 - Flaques",
                        "4":"4 - Inondée",
                        "5":"5 - Enneigée",
                        "6":"6 - Boue",
                        "7":"7 - Verglacée",
                        "8":"8 - Corps gras - huile",
                        "9":"9 - Autre"},

                "infra":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun",
                        "1":"1 - Souterrain - tunnel",
                        "2":"2 - Pont - autopont",
                        "3":"3 - Bretelle d'échangeur ou de raccordement",
                        "4":"4 - Voie ferrée",
                        "5":"5 - Carrefour aménagé",
                        "6":"6 - Zone piétonne",
                        "7":"7 - Zone de péage",
                        "8":"8 - Chantier",
                        "9":"9 - Autres"},

                "situ":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun",
                        "1":"1 - Sur chaussée",
                        "2":"2 - Sur bande d'arrêt d'urgence",
                        "3":"3 - Sur accotement",
                        "4":"4 - Sur trottoir",
                        "4":"5 - Sur piste cyclable",
                        "5":"6 - Sur autre voie spéciale",
                        "8":"8 - Autres"},

                

                         
        }

# %%
mapping_vehicules = {"senc":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Inconnu",
                        "1":"1 - PK ou PR ou numéro d'adresse postale croissant",
                        "2":"2 - PK ou PR ou numéro"},    
    
                    "catv":{
                        "0":"00 - Indéterminable",
                        "1":"01 - Bicyclette",
                        "2":"02 - Cyclomoteur <50cm3",
                        "3":"03 - Voiturette (Quadricycle à moteur carrossé) (anciennement \"voiturette ou tricycle à moteur\")",
                        "4":"04 - Référence inutilisée depuis 2006 (scooter immatriculé)",
                        "5":"05 - Référence inutilisée depuis 2006 (motocyclette)",
                        "6":"06 - Référence inutilisée depuis 2006 (side-car)",
                        "7":"07 - VL seul",
                        "8":"08 - Référence inutilisée depuis 2006 (VL + caravane)",
                        "9":"09 - Référence inutilisée depuis 2006 (VL + remorque)",
                        "10":"10 - VU seul 1,5T <= PTAC <= 3,5T avec ou sans remorque (anciennement VU seul 1,5T <= PTAC <= 3,5T)",
                        "11":"11 - Référence inutilisée depuis 2006 (VU (10) + caravane)",
                        "12":"12 - Référence inutilisée depuis 2006 (VU (10) + remorque)",
                        "13":"13 - PL seul 3,5T <PTCA <= 7,5T",
                        "14":"14 - PL seul > 7,5T",
                        "15":"15 - PL > 3,5T + remorque",
                        "16":"16 - Tracteur routier seul",
                        "17":"17 - Tracteur routier + semi-remorque",
                        "18":"18 - Référence inutilisée depuis 2006 (transport en commun)",
                        "19":"19 - Référence inutilisée depuis 2006 (tramway)",
                        "20":"20 - Engin spécial",
                        "21":"21 - Tracteur agricole",
                        "30":"30 - Scooter < 50 cm3",
                        "31":"31 - Motocyclette > 50 cm3 et <= 125 cm3",
                        "32":"32 - Scooter > 50 cm3 et <= 125 cm3",
                        "33":"33 - Motocyclette > 125 cm3",
                        "34":"34 - Scooter > 125 cm3",
                        "35":"35 - Quad léger <= 50 cm3 (Quadricycle à moteur non carrossé)",
                        "36":"36 - Quad lourd > 50 cm3 (Quadricycle à moteur non carrossé)",
                        "37":"37 - Autobus",
                        "38":"38 - Autocar",
                        "39":"39 - Train",
                        "40":"40 - Tramway",
                        "41":"41 - 3RM <= 50 cm3",
                        "42":"42 - 3RM > 50 cm3 <= 125 cm3",
                        "43":"43 - 3RM > 125 cm3",
                        "50":"50 - EDP à moteur",
                        "60":"60 - EDP sans moteur",
                        "80":"80 - VAE",
                        "99":"99 - Autre véhicule"},

                    "obs":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Sans objet",
                        "1":"1 - Véhicule en stationnement",
                        "2":"2 - Arbre",
                        "3":"3 - Glissière métallique",
                        "4":"4 - Glissière béton",
                        "5":"5 - Autre glissière",
                        "6":"6 - Bâtiment, mur, pile de pont",
                        "7":"7 - Support de signalisation verticale ou poste d'appel d'urgence",
                        "8":"8 - Poteau",
                        "9":"9 - Mobilier urbain",
                        "10":"10 - Parapet",
                        "11":"11 - Ilot, refuge, borne haute",
                        "12":"12 - Bordure de trottoir",
                        "13":"13 - Fossé, talus, paroi rocheuse",
                        "14":"14 - Autre obstacle fixe sur chaussée",
                        "15":"15 - Autre obstacle fixe sur trottoir ou accotement",
                        "16":"16 - Sortie de chaussée sans obstacle",
                        "17":"17 - Buse - tête d'aqueduc"
                    },

                    "obsm":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun",
                        "1":"1 - Piéton",
                        "2":"2 - Véhicule",
                        "4":"4 - Véhicule sur rail",
                        "5":"5 - Animal domestique",
                        "6":"6 - Animal sauvage",
                        "9":"9 - Autre"},

                    "choc":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun",
                        "1":"1 - Avant",
                        "2":"2 - Avant droit",
                        "3":"3 - Avant gauche",
                        "4":"4 - Arrière",
                        "5":"5 - Arrière droit",
                        "6":"6 - Arrière gauche",
                        "7":"7 - Côté droit",
                        "8":"8 - Côté gauche",
                        "9":"9 - Chocs multiples (tonneaux)"},


                "manv":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Inconnue",
                        "1":"1 - Sans changement de direction",
                        "2":"2 - Même sens, même file",
                        "3":"3 - Entre 2 files",
                        "4":"4 - En marche arrière",
                        "5":"5 - A contresens",
                        "6":"6 - En franchissant le terre-plein central",
                        "7":"7 - Dans le couloir bus, dans le même sens",
                        "8":"8 - Dans le couloir bus, dans le sens inverse",
                        "9":"9 - En s'insérant",
                        "10":"10 - En faisant demi-tour sur la chaussée",
                        "11":"11 - Changeant de file - A gauche",
                        "12":"12 - Changeant de file - A droite",
                        "13":"13 - Déporté - A gauche",
                        "14":"14 - Déporté - A droite",
                        "15":"15 - Tournant - A gauche",
                        "16":"16 - Tournant - A droite",
                        "17":"17 - Dépassant - A gauche",
                        "18":"18 - Dépassant - A droite",
                        "19":"19 - Traversant la chaussée",
                        "20":"20 - Manoeuvre de stationnement",
                        "21":"21 - Manoeuvre d'évitement",
                        "22":"22 - Ouverture de porte",
                        "23":"23 - Arrêté (hors stationnement)",
                        "24":"24 - En stationnement (avec occupants)",
                        "25":"25 - Circulant sur trottoir",
                        "26":"26 - Autres manoeuvres"},
                    "motor":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Inconnue",
                        "1":"1 - Hydrocarbures",
                        "2":"2 - Hybride électrique",
                        "3":"3 - Electrique",
                        "4":"4 - Hydrogène",
                        "5":"5 - Humaine",
                        "6":"6 - Autre"}
}

# %%
mapping_usagers = {
                    "catu":{
                        "1":"1 - Conducteur",
                        "2":"2 - Passager",
                        "3":"3 - Piéton"},

                    "grav":{
                        "1":"1 - Indemne",
                        "2":"2 - Tué",
                        "3":"3 - Blessé hospitalisé",
                        "4":"4 - Blessé léger"},

                    "sexe":{
                        "1":"1 - Masculin",
                        "2":"2 - Féminin"},

                    
                    "trajet":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Non renseigné",
                        "1":"1 - Domicile - travail",
                        "2":"2 - Domicile - école",
                        "3":"3 - Courses - achats",
                        "4":"4 - Utilisation professionnelle",
                        "5":"5 - Promenade - loisirs",
                        "9":"9 - Autre"},

                    "secu1":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun équipement",
                        "1":"1 - Ceinture",
                        "2":"2 - Casque",
                        "3":"3 - Dispositif enfants",
                        "4":"4 - Gilet réfléchissant",
                        "5":"5 - Airbag (2RM/3RM)",
                        "6":"6 - Gants (2RM/3RM)",
                        "7":"7 - Gants + Airbag (2RM/3RM)",
                        "8":"8 - Non déterminable",
                        "9":"9 - Autre"},
                    "secu2":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun équipement",
                        "1":"1 - Ceinture",
                        "2":"2 - Casque",
                        "3":"3 - Dispositif enfants",
                        "4":"4 - Gilet réfléchissant",
                        "5":"5 - Airbag (2RM/3RM)",
                        "6":"6 - Gants (2RM/3RM)",
                        "7":"7 - Gants + Airbag (2RM/3RM)",
                        "8":"8 - Non déterminable",
                        "9":"9 - Autre"},
                    "secu3":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Aucun équipement",
                        "1":"1 - Ceinture",
                        "2":"2 - Casque",
                        "3":"3 - Dispositif enfants",
                        "4":"4 - Gilet réfléchissant",
                        "5":"5 - Airbag (2RM/3RM)",
                        "6":"6 - Gants (2RM/3RM)",
                        "7":"7 - Gants + Airbag (2RM/3RM)",
                        "8":"8 - Non déterminable",
                        "9":"9 - Autre"},

                    "locp":{
                        "9":"-1 - Non renseigné",
                        "0":"0 - Sans objet",
                        "1":"1 - Sur chaussée : A + 50 m du passage piéton",
                        "2":"2 - Sur chaussée : A - 50 m du passage piéton",
                        "3":"3 - Sur passage piéton : Sans signalisation lumineuse",
                        "4":"4 - Sur passage piéton : Avec signalisation lumineuse",
                        "5":"5 - Sur trottoir",
                        "6":"6 - Sur accotement",
                        "7":"7 - Sur refuge ou BAU",
                        "8":"8 - Sur contre allée",
                        "9":"9 - Inconnue"},

                "actp":{
                        "-1":"-1 - Non renseigné",
                        "0":"0 - Non renseigné ou sans objet",
                        "1":"1 - Sens véhicule heurtant",
                        "2":"2 - Sens inverse du véhicule",
                        "3":"3 - Traversant",
                        "4":"4 - Masqué",
                        "5":"5 - Jouant - courant",
                        "6":"6 - Avec animal",
                        "9":"9 - Autre",
                        "A":"A - Monte/descend du véhicule",
                        "B":"B - Inconnue",
                        },

               "etatp":{
                        "-1":"-1 - Non renseigné",
                        "1":"1 - Seul",
                        "2":"2 - Accompagné",
                        "3":"3 - En groupe"}
}

# %%
for k in mapping_caracteristiques.keys():
    df_caracteristiques[k] = df_caracteristiques[k].apply(lambda x: mapping_caracteristiques.get(k).get(x))

# %%
for k in mapping_lieux.keys():
    df_lieux[k] = df_lieux[k].apply(lambda x: mapping_lieux.get(k).get(x))

# %%
for k in mapping_vehicules.keys():
    df_vehicules[k] = df_vehicules[k].apply(lambda x: mapping_vehicules.get(k).get(x))

# %%
for k in mapping_usagers.keys():
    df_usagers[k] = df_usagers[k].apply(lambda x : mapping_usagers.get(k).get(x))

# %% [markdown]
# RENOMMER LES COLONNES

# %%
col_caracteristiques = {"Num_Acc":"Accident_Id","jour":"Jour","mois":"Mois","an":"Année","hrmn":"Heure","lum":"Lumière", "dep":"Département", "com":"Commune", "agg":"Agglomération", "int":"Intersection",
                        "atm":"Conditions atmosphériques", "col":"Type de collision", "adr":"Adresse", "lat":"Latitude", "long":"Longitude"}

col_lieux = {'Num_Acc':"Accident_Id", 'catr':"Catégorie de route", 'voie':"Nom de la route", 'v1':"Indice numérique", 'v2':"Indice numérique 2", 'circ':"Régime de circulation", 
             'nbv':"Nombre total de voies de circulation", 'vosp':"Voie réservée", 'prof':"Profil",
       'pr':"Numéro de la borne amont", 'pr1':"Distance en mètres", 'plan':"Tracé", 'lartpc':"Largeur du terre-plein central", 'larrout':"Largeur de la chaussée", 
       'surf':"Etat de la surface", 'infra':"Infrastructure", 'situ':"Situation de l'accident", 'vma':"Vitesse maximale autorisée"}

col_vehicules = {"Num_Acc":"Accident_Id",'id_vehicule':"Véhicule_Id", 'num_veh':"Numéro du véhicule", 'senc':"Sens de circulation", 'catv':"Catégorie du véhicule", 'obs':"Obstacle fixe heurté", 'obsm':"Obstacle mobile heurté",
       'choc':"Point de choc initial", 'manv':"Manoeuvre principale avant l'accident", 'motor':"Type de motorisation", 'occutc':"Nombre d'occupants dans le transport en commun"}

col_usagers = {"Num_Acc":"Accident_Id",'id_vehicule':"Véhicule_Id", 'num_veh':"Numéro du véhicule", 'place':"Place dans le véhicule", 'catu':"Catégorie usager", 
               'grav':"Gravité des blessures",'sexe':"Sexe", 'an_nais':"Année de naissance", 'trajet':"Motif du déplacement", 
               'secu1':"Equipement de sécurité 1", 'secu2':"Equipement de sécurité 2", 'secu3':"Equipement de sécurité 3", 'locp':"Localisation du piéton", 
               'actp':"Action du piéton", 'etatp':"Accompagnement piéton", 'id_usager':"Usager_Id"}

# %%
df_caracteristiques=df_caracteristiques.rename(columns=col_caracteristiques)
df_lieux=df_lieux.rename(columns=col_lieux)
df_vehicules= df_vehicules.rename(columns=col_vehicules)
df_usagers = df_usagers.rename(columns=col_usagers)

# %% [markdown]
# ON SAUVEGARDE LES FICHIERS CSV

# %%
df_caracteristiques.to_csv('cleaned_files/caractéristiques_clean.csv', sep=';',index=False)
df_lieux.to_csv('cleaned_files/lieux_clean.csv', sep=';',index=False)
df_vehicules.to_csv('cleaned_files/véhicules_clean.csv', sep=';',index=False)
df_usagers.to_csv('cleaned_files/usagers_clean.csv', sep=';',index=False)

# %%
df_caracteristiques.shape
# Out:
# (273226, 15)
